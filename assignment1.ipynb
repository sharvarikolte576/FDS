# %%
import numpy as np 
arr = np.array([2,4,6,8])
print(arr)
# Out:
# [2 4 6 8]

# %%
import numpy as np 
arr = np.array([2,4,6,8])
print(np.sum(arr))
# Out:
# 20

# %%
import numpy as np 
arr = np.array([2,4,6,8])
print(np.mean(arr))
# Out:
# 5.0
